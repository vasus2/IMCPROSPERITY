# %%
import pandas as pd
import matplotlib.pyplot as plt
from wavelet import WaveletTransform, getExponent
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df = pd.read_csv("prices_round_1_day_0.csv", delimiter=";")
starfruit = df[df['product'] == "STARFRUIT"]
plt.plot(range(1,10001), starfruit["mid_price"])

# %%
t = 10
mses = []
full_signal = []
for m in range(t, 10000, t):
    n=6
    filtered = np.array(starfruit[m-t:m]["mid_price"])
    transform = WaveletTransform(waveletName="db4")
    coefficients = transform.dwt(filtered, level=n)
    reconstructed_signal = np.array(transform.idwt(coefficients, level=n))
    
    futures = Amethysts[m+1:m+n+1]["mid_price"]
    full_signal.append(reconstructed_signal)

#     mse = ((futures-reconstructed_signal)**2).mean()
#     mses.append(mse)

# %%
full_signal
# Out:
# [array([5040.70512255, 5039.70568877, 5041.1170663 , 5040.52240088,
#         5041.17781116, 5038.77191035]),
#  array([5039.78658323, 5043.01775372, 5039.86759633, 5038.93568721,
#         5039.34582044, 5037.54655907]),
#  array([5041.34778244, 5039.01433716, 5036.22928074, 5039.9509263 ,
#         5041.42293682, 5039.53473654]),
#  array([5037.37756884, 5037.86946562, 5037.99189677, 5038.08051924,
#         5037.63053438, 5037.55001514]),
#  array([5038.98379355, 5038.83348478, 5037.68865274, 5037.83896151,
#         5038.32755371, 5038.32755371]),
#  array([5035.25730984, 5035.30598239, 5037.723291  , 5036.14152746,
#         5037.01939916, 5033.05249015]),
#  array([5033.29251431, 5037.20640647, 5032.21135649, 5033.27464872,
#         5032.49612921, 5033.51894481]),
#  array([5032.91948076, 5033.48322733, 5033.98915841, 5032.76917199,
#         5032.59136083, 5033.24760068]),
#  array([5035.63672881, 5033.93021048, 5033.55811836, 5033.63383896,
# ...

# %%
t = 320
for m in range(t, 10000, t):
    n=20
    filtered = np.array(Amethysts[m-t:m]["mid_price"])
    transform = WaveletTransform(waveletName="db4")
    coefficients = transform.dwt(filtered, level=n)
    reconstructed_signal = np.array(transform.idwt(coefficients, level=n))
    
    futures = Amethysts[m+1:m+n+1]["mid_price"]
    mse = ((futures-reconstructed_signal)**2).mean()
